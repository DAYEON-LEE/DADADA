# %%
import pandas as pd

# %%
CCTV_Seoul = pd.read_excel('C:/Users/user1/Desktop/파이썬으로 데이터 주무르기(책)/DATA/CCTV_Seoul.xlsx',encoding = 'utf-8')
CCTV_Seoul.head()
# Out:
#      기관명    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 0  강 남 구  5221    1944.0  195.0  316.0    430    546    765    577    448
# 1  강 동 구  1879     303.0  387.0  134.0     59    144    194    273    385
# 2  강 북 구  1265     243.0   88.0  141.0     74    145    254      1    319
# 3  강 서 구  1617     219.0  155.0  118.0    230    187    190    264    254
# 4  관 악 구  3985     430.0   56.0  419.0    487    609    619    694    671

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\user1\\Desktop\\파이썬으로 데이터 주무르기(책)\\Chapter1'

# %%
os.chdir('C:\\Users\\user1\\Desktop\\파이썬으로 데이터 주무르기(책)')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\user1\\Desktop\\파이썬으로 데이터 주무르기(책)'

# %%
CCTV_Seoul.columns
# Out:
# Index(['기관명', '소계', '2011년 이전', '2012년', '2013년', '2014년', '2015년', '2016년',
#        '2017년', '2018년'],
#       dtype='object')

# %%
CCTV_Seoul.columns[0]
# Out:
# '기관명'

# %%
CCTV_Seoul.rename(columns = {CCTV_Seoul.columns[0] : '구별'},inplace = True)
CCTV_Seoul.head()
# Out:
#       구별    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 0  강 남 구  5221    1944.0  195.0  316.0    430    546    765    577    448
# 1  강 동 구  1879     303.0  387.0  134.0     59    144    194    273    385
# 2  강 북 구  1265     243.0   88.0  141.0     74    145    254      1    319
# 3  강 서 구  1617     219.0  155.0  118.0    230    187    190    264    254
# 4  관 악 구  3985     430.0   56.0  419.0    487    609    619    694    671

# %%
os.getcwd()
# Out:
# 'C:\\Users\\user1\\Desktop\\파이썬으로 데이터 주무르기(책)'

# %%
pop_Seoul = pd.read_excel('./DATA/population_in_Seoul.xlsx',
                       header =2,
                       usecols = 'B,D,G,J,N',
                       encoding = 'utf-8')
pop_Seoul.head()
# Out:
#    자치구         계      계.1     계.2  65세이상고령자
# 0   합계  10013781  9733655  280126   1518239
# 1  종로구    161984   151217   10767     28073
# 2   중구    136469   126175   10294     23794
# 3  용산구    246165   229579   16586     39439
# 4  성동구    307193   299042    8151     44728

# %%
pop_Seoul.rename(columns = {pop_Seoul.columns[0] : '구별',
                           pop_Seoul.columns[1] : '인구수',
                           pop_Seoul.columns[2] : '한국인',
                           pop_Seoul.columns[3] : '외국인',
                           pop_Seoul.columns[4] : '고령자'},inplace = True)
pop_Seoul.head()
# Out:
#     구별       인구수      한국인     외국인      고령자
# 0   합계  10013781  9733655  280126  1518239
# 1  종로구    161984   151217   10767    28073
# 2   중구    136469   126175   10294    23794
# 3  용산구    246165   229579   16586    39439
# 4  성동구    307193   299042    8151    44728

# %%
import numpy as np

# %%
s = pd.Series([1,3,np.nan,4,5,6])
s
# Out:
# 0    1.0
# 1    3.0
# 2    NaN
# 3    4.0
# 4    5.0
# 5    6.0
# dtype: float64

# %%
dates = pd.date_range('20130101',periods = 6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index = dates, columns = ['A','B','C','D'])
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.355865 -0.071117  1.039083 -0.244723
# 2013-01-02  0.254195 -0.058276  0.194235  1.550017
# 2013-01-03  0.154408 -1.174607  0.230687  0.844755
# 2013-01-04  0.453319  0.239837 -0.404803  1.802137
# 2013-01-05  2.205870 -0.099328 -0.309868  0.852950
# 2013-01-06 -0.943458 -1.104631 -0.197059 -1.129649

# %%
df.head(3)
# Out:
#                    A         B         C         D
# 2013-01-01 -0.355865 -0.071117  1.039083 -0.244723
# 2013-01-02  0.254195 -0.058276  0.194235  1.550017
# 2013-01-03  0.154408 -1.174607  0.230687  0.844755

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[-0.35586481, -0.07111656,  1.03908347, -0.24472265],
#        [ 0.254195  , -0.0582763 ,  0.19423502,  1.55001715],
#        [ 0.15440835, -1.17460676,  0.23068688,  0.84475478],
#        [ 0.453319  ,  0.23983682, -0.4048034 ,  1.80213735],
#        [ 2.2058696 , -0.09932839, -0.30986781,  0.8529497 ],
#        [-0.94345778, -1.10463112, -0.19705862, -1.12964875]])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6 entries, 2013-01-01 to 2013-01-06
# Freq: D
# Data columns (total 4 columns):
# A    6 non-null float64
# B    6 non-null float64
# C    6 non-null float64
# D    6 non-null float64
# dtypes: float64(4)
# memory usage: 240.0 bytes

# %%
df.sort_values(by='B',ascending = False)
# Out:
#                    A         B         C         D
# 2013-01-04  0.453319  0.239837 -0.404803  1.802137
# 2013-01-02  0.254195 -0.058276  0.194235  1.550017
# 2013-01-01 -0.355865 -0.071117  1.039083 -0.244723
# 2013-01-05  2.205870 -0.099328 -0.309868  0.852950
# 2013-01-06 -0.943458 -1.104631 -0.197059 -1.129649
# 2013-01-03  0.154408 -1.174607  0.230687  0.844755

# %%
df.loc[dates[0]]
# Out:
# A   -0.355865
# B   -0.071117
# C    1.039083
# D   -0.244723
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:,['A','B']]
# Out:
#                    A         B
# 2013-01-01 -0.355865 -0.071117
# 2013-01-02  0.254195 -0.058276
# 2013-01-03  0.154408 -1.174607
# 2013-01-04  0.453319  0.239837
# 2013-01-05  2.205870 -0.099328
# 2013-01-06 -0.943458 -1.104631

# %%
df['E'] = ['one','one','two','three','four','three']
df
# Out:
#                    A         B         C         D      E
# 2013-01-01 -0.355865 -0.071117  1.039083 -0.244723    one
# 2013-01-02  0.254195 -0.058276  0.194235  1.550017    one
# 2013-01-03  0.154408 -1.174607  0.230687  0.844755    two
# 2013-01-04  0.453319  0.239837 -0.404803  1.802137  three
# 2013-01-05  2.205870 -0.099328 -0.309868  0.852950   four
# 2013-01-06 -0.943458 -1.104631 -0.197059 -1.129649  three

# %%
df['E'].isin(['two','four'])
# Out:
# 2013-01-01    False
# 2013-01-02    False
# 2013-01-03     True
# 2013-01-04    False
# 2013-01-05     True
# 2013-01-06    False
# Freq: D, Name: E, dtype: bool

# %%
df[df['E'].isin(['two','four'])]
# Out:
#                    A         B         C         D     E
# 2013-01-03  0.154408 -1.174607  0.230687  0.844755   two
# 2013-01-05  2.205870 -0.099328 -0.309868  0.852950  four

# %%
df =df.drop('E',axis=1)

# %%
df.apply(lambda x : x.max()-x.min())
# Out:
# A    3.149327
# B    1.414444
# C    1.443887
# D    2.931786
# dtype: float64

# %%
CCTV_Seoul.sort_values(by='소계',ascending = True).head()
# Out:
#          구별    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 9     도 봉 구   858     197.0   66.0    8.0    185     59    155    117     71
# 24    중 랑 구  1068       NaN    NaN    NaN    770    102    121     66      9
# 2     강 북 구  1265     243.0   88.0  141.0     74    145    254      1    319
# 22    종 로 구  1471       8.0    7.0  599.0    132    195    148    281    101
# 23  중     구  1544      25.0  165.0  114.0     80    245    270    317    328

# %%
CCTV_Seoul.sort_values(by='소계',ascending = False).head()
# Out:
#        구별    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 0   강 남 구  5221    1944.0  195.0  316.0    430    546    765    577    448
# 4   관 악 구  3985     430.0   56.0  419.0    487    609    619    694    671
# 6   구 로 구  3227     852.0  219.0  349.0    187    268    326    540    486
# 16  성 북 구  3003     779.0   84.0  304.0    241    279    388    285    643
# 21  은 평 구  2962    1365.0   83.0   99.0    343    180    296    229    367

# %%
CCTV_Seoul['최근증가율'] = (CCTV_Seoul['2012년']+CCTV_Seoul['2013년']+CCTV_Seoul['2014년']+CCTV_Seoul['2015년']+CCTV_Seoul['2016년']+CCTV_Seoul['2017년']+CCTV_Seoul['2018년']/CCTV_Seoul['2011년 이전']*100)

# %%
CCTV_Seoul.head()
# Out:
#       구별    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0  강 남 구  5221    1944.0  195.0  316.0    430    546    765    577    448
# 1  강 동 구  1879     303.0  387.0  134.0     59    144    194    273    385
# 2  강 북 구  1265     243.0   88.0  141.0     74    145    254      1    319
# 3  강 서 구  1617     219.0  155.0  118.0    230    187    190    264    254
# 4  관 악 구  3985     430.0   56.0  419.0    487    609    619    694    671
#
#          최근증가율
# 0  2852.045267
# 1  1318.062706
# 2   834.275720
# 3  1259.981735
# 4  3040.046512

# %%
pop_Seoul.head()
# Out:
#     구별       인구수      한국인     외국인      고령자
# 0   합계  10013781  9733655  280126  1518239
# 1  종로구    161984   151217   10767    28073
# 2   중구    136469   126175   10294    23794
# 3  용산구    246165   229579   16586    39439
# 4  성동구    307193   299042    8151    44728

# %%
pop_Seoul.drop(0,axis=0,inplace = True)
pop_Seoul.head()
# Out:
#     구별     인구수     한국인    외국인    고령자
# 1  종로구  161984  151217  10767  28073
# 2   중구  136469  126175  10294  23794
# 3  용산구  246165  229579  16586  39439
# 4  성동구  307193  299042   8151  44728
# 5  광진구  365990  350417  15573  48989

# %%
pop_Seoul['구별'].unique()
# Out:
# array(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구',
#        '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'], dtype=object)

# %%
pop_Seoul[pop_Seoul['구별'].isnull()]
# Out:
# Empty DataFrame
# Columns: [구별, 인구수, 한국인, 외국인, 고령자]
# Index: []

# %%
pop_Seoul.isnull().sum()
# Out:
# 구별     0
# 인구수    0
# 한국인    0
# 외국인    0
# 고령자    0
# dtype: int64

# %%
pop_Seoul['외국인비율'] = pop_Seoul['외국인']/pop_Seoul['인구수']*100
pop_Seoul['고령자비율'] = pop_Seoul['고령자']/pop_Seoul['인구수']*100
pop_Seoul.head()
# Out:
#     구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 1  종로구  161984  151217  10767  28073  6.646953  17.330724
# 2   중구  136469  126175  10294  23794  7.543105  17.435462
# 3  용산구  246165  229579  16586  39439  6.737757  16.021368
# 4  성동구  307193  299042   8151  44728  2.653381  14.560228
# 5  광진구  365990  350417  15573  48989  4.255034  13.385338

# %%
pop_Seoul.sort_values(by='인구수',ascending = False).head()
# Out:
#      구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 24  송파구  680883  674095   6788  89539  0.996941  13.150424
# 16  강서구  595703  589302   6401  85992  1.074529  14.435381
# 23  강남구  549898  544804   5094  72602  0.926354  13.202812
# 11  노원구  535495  531037   4458  82682  0.832501  15.440294
# 21  관악구  516662  499374  17288  76664  3.346095  14.838328

# %%
pop_Seoul.sort_values(by='외국인',ascending = False).head()
# Out:
#       구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 19  영등포구  404766  371903  32863  59373  8.119012  14.668475
# 17   구로구  438308  405837  32471  67432  7.408261  15.384615
# 18   금천구  251370  232583  18787  38508  7.473843  15.319251
# 21   관악구  516662  499374  17288  76664  3.346095  14.838328
# 6   동대문구  362793  346156  16637  60367  4.585811  16.639516

# %%
pop_Seoul.sort_values(by='외국인비율',ascending = False).head()
# Out:
#       구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 19  영등포구  404766  371903  32863  59373  8.119012  14.668475
# 2     중구  136469  126175  10294  23794  7.543105  17.435462
# 18   금천구  251370  232583  18787  38508  7.473843  15.319251
# 17   구로구  438308  405837  32471  67432  7.408261  15.384615
# 3    용산구  246165  229579  16586  39439  6.737757  16.021368

# %%
pop_Seoul.sort_values(by='고령자',ascending = False).head()
# Out:
#      구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 24  송파구  680883  674095   6788  89539  0.996941  13.150424
# 16  강서구  595703  589302   6401  85992  1.074529  14.435381
# 11  노원구  535495  531037   4458  82682  0.832501  15.440294
# 12  은평구  482509  478019   4490  82245  0.930553  17.045278
# 21  관악구  516662  499374  17288  76664  3.346095  14.838328

# %%
pop_Seoul.sort_values(by='고령자비율',ascending = False).head()
# Out:
#      구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 9   강북구  316750  312985   3765  61660  1.188635  19.466456
# 10  도봉구  333495  331238   2257  60023  0.676772  17.998171
# 2    중구  136469  126175  10294  23794  7.543105  17.435462
# 1   종로구  161984  151217  10767  28073  6.646953  17.330724
# 12  은평구  482509  478019   4490  82245  0.930553  17.045278

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.355865 -0.071117  1.039083 -0.244723
# 2013-01-02  0.254195 -0.058276  0.194235  1.550017
# 2013-01-03  0.154408 -1.174607  0.230687  0.844755
# 2013-01-04  0.453319  0.239837 -0.404803  1.802137
# 2013-01-05  2.205870 -0.099328 -0.309868  0.852950
# 2013-01-06 -0.943458 -1.104631 -0.197059 -1.129649

# %%
df['A'].map(lambda x : '%02d'%x)
# Out:
# 2013-01-01    00
# 2013-01-02    00
# 2013-01-03    00
# 2013-01-04    00
# 2013-01-05    02
# 2013-01-06    00
# Freq: D, Name: A, dtype: object

# %%
list(map(lambda x : '%02d'%x , df['A']))
# Out:
# ['00', '00', '00', '00', '02', '00']

# %%
pop_Seoul
# Out:
#       구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 1    종로구  161984  151217  10767  28073  6.646953  17.330724
# 2     중구  136469  126175  10294  23794  7.543105  17.435462
# 3    용산구  246165  229579  16586  39439  6.737757  16.021368
# 4    성동구  307193  299042   8151  44728  2.653381  14.560228
# 5    광진구  365990  350417  15573  48989  4.255034  13.385338
# 6   동대문구  362793  346156  16637  60367  4.585811  16.639516
# 7    중랑구  400678  395619   5059  66764  1.262610  16.662757
# 8    성북구  454532  442494  12038  72172  2.648438  15.878310
# 9    강북구  316750  312985   3765  61660  1.188635  19.466456
# 10   도봉구  333495  331238   2257  60023  0.676772  17.998171
# 11   노원구  535495  531037   4458  82682  0.832501  15.440294
# 12   은평구  482509  478019   4490  82245  0.930553  17.045278
# 13  서대문구  325875  312642  13233  53038  4.060759  16.275566
# 14   마포구  386086  374570  11516  53283  2.982755  13.800811
# 15   양천구  460532  456339   4193  62761  0.910469  13.627935
# ...

# %%
CCTV_Seoul
# Out:
#          구별    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0     강 남 구  5221    1944.0  195.0  316.0    430    546    765    577    448
# 1     강 동 구  1879     303.0  387.0  134.0     59    144    194    273    385
# 2     강 북 구  1265     243.0   88.0  141.0     74    145    254      1    319
# 3     강 서 구  1617     219.0  155.0  118.0    230    187    190    264    254
# 4     관 악 구  3985     430.0   56.0  419.0    487    609    619    694    671
# 5     광 진 구  1581     470.0   42.0   83.0     87     64     21    468    346
# 6     구 로 구  3227     852.0  219.0  349.0    187    268    326    540    486
# 7     금 천 구  1634      27.0   17.0  242.0    101    382    136    199    530
# 8     노 원 구  1906     481.0  117.0  203.0     80    461    298    110    156
# 9     도 봉 구   858     197.0   66.0    8.0    185     59    155    117     71
# 10     동대문구  2003       NaN    NaN    NaN   1326    111    233    136    197
# ...

# %%
CCTV_Seoul['구별'] = CCTV_Seoul['구별'].map(lambda x : x.replace(' ',''))
CCTV_Seoul['구별'].head()
# Out:
# 0    강남구
# 1    강동구
# 2    강북구
# 3    강서구
# 4    관악구
# Name: 구별, dtype: object

# %%
len(CCTV_Seoul)
# Out:
# 25

# %%
CCTV_Seoul['구별'].unique()
# Out:
# array(['강 남 구', '강 동 구', '강 북 구', '강 서 구', '관 악 구', '광 진 구', '구 로 구',
#        '금 천 구', '노 원 구', '도 봉 구', '동대문구', '동 작 구', '마 포 구', '서대문구',
#        '서 초 구', '성 동 구', '성 북 구', '송 파 구', '양 천 구', '영등포구', '용 산 구',
#        '은 평 구', '종 로 구', '중     구', '중 랑 구'], dtype=object)

# %%
len(pop_Seoul)
# Out:
# 25

# %%
CCTV_Seoul['구별'].unique()
# Out:
# array(['강 남 구', '강 동 구', '강 북 구', '강 서 구', '관 악 구', '광 진 구', '구 로 구',
#        '금 천 구', '노 원 구', '도 봉 구', '동대문구', '동 작 구', '마 포 구', '서대문구',
#        '서 초 구', '성 동 구', '성 북 구', '송 파 구', '양 천 구', '영등포구', '용 산 구',
#        '은 평 구', '종 로 구', '중     구', '중 랑 구'], dtype=object)

# %%
CCTV_Seoul.sort_values(by='구별',inplace=True)
CCTV_Seoul.head()
# Out:
#     구별    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0  강남구  5221    1944.0  195.0  316.0    430    546    765    577    448
# 1  강동구  1879     303.0  387.0  134.0     59    144    194    273    385
# 2  강북구  1265     243.0   88.0  141.0     74    145    254      1    319
# 3  강서구  1617     219.0  155.0  118.0    230    187    190    264    254
# 4  관악구  3985     430.0   56.0  419.0    487    609    619    694    671
#
#          최근증가율
# 0  2852.045267
# 1  1318.062706
# 2   834.275720
# 3  1259.981735
# 4  3040.046512

# %%
pop_Seoul.sort_values(by='구별',inplace=True)
pop_Seoul.head()
# Out:
#      구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 23  강남구  549898  544804   5094  72602  0.926354  13.202812
# 25  강동구  457042  452646   4396  66401  0.961837  14.528424
# 9   강북구  316750  312985   3765  61660  1.188635  19.466456
# 16  강서구  595703  589302   6401  85992  1.074529  14.435381
# 21  관악구  516662  499374  17288  76664  3.346095  14.838328

# %%
pop_Seoul.reset_index(inplace=True)
del pop_Seoul['index']
pop_Seoul.head()
# Out:
#     구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 0  강남구  549898  544804   5094  72602  0.926354  13.202812
# 1  강동구  457042  452646   4396  66401  0.961837  14.528424
# 2  강북구  316750  312985   3765  61660  1.188635  19.466456
# 3  강서구  595703  589302   6401  85992  1.074529  14.435381
# 4  관악구  516662  499374  17288  76664  3.346095  14.838328

# %%
data_result = pd.merge(CCTV_Seoul,pop_Seoul,on='구별')
data_result.head()
# Out:
#     구별    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0  강남구  5221    1944.0  195.0  316.0    430    546    765    577    448
# 1  강동구  1879     303.0  387.0  134.0     59    144    194    273    385
# 2  강북구  1265     243.0   88.0  141.0     74    145    254      1    319
# 3  강서구  1617     219.0  155.0  118.0    230    187    190    264    254
# 4  관악구  3985     430.0   56.0  419.0    487    609    619    694    671
#
#          최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 0  2852.045267  549898  544804   5094  72602  0.926354  13.202812
# 1  1318.062706  457042  452646   4396  66401  0.961837  14.528424
# 2   834.275720  316750  312985   3765  61660  1.188635  19.466456
# 3  1259.981735  595703  589302   6401  85992  1.074529  14.435381
# 4  3040.046512  516662  499374  17288  76664  3.346095  14.838328

# %%
del data_result['2011년 이전']
del data_result['2012년']
del data_result['2013년']
del data_result['2014년']
del data_result['2015년']
del data_result['2016년']
del data_result['2017년']
del data_result['2018년']

# %%
data_result
# Out:
#       구별    소계        최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 0    강남구  5221  2852.045267  549898  544804   5094  72602  0.926354  13.202812
# 1    강동구  1879  1318.062706  457042  452646   4396  66401  0.961837  14.528424
# 2    강북구  1265   834.275720  316750  312985   3765  61660  1.188635  19.466456
# 3    강서구  1617  1259.981735  595703  589302   6401  85992  1.074529  14.435381
# 4    관악구  3985  3040.046512  516662  499374  17288  76664  3.346095  14.838328
# 5    광진구  1581   838.617021  365990  350417  15573  48989  4.255034  13.385338
# 6    구로구  3227  1946.042254  438308  405837  32471  67432  7.408261  15.384615
# 7    금천구  1634  3039.962963  251370  232583  18787  38508  7.473843  15.319251
# 8    노원구  1906  1301.432432  535495  531037   4458  82682  0.832501  15.440294
# 9    도봉구   858   626.040609  333495  331238   2257  60023  0.676772  17.998171
# 10  동대문구  2003          NaN  362793  346156  16637  60367  4.585811  16.639516
# ...

# %%
data_result.isnull().sum()
# Out:
# 구별       0
# 소계       0
# 최근증가율    2
# 인구수      0
# 한국인      0
# 외국인      0
# 고령자      0
# 외국인비율    0
# 고령자비율    0
# dtype: int64

# %% [markdown]
# 최근증가율 결측치(NaN)2개는 동대문구, 중랑구의 경우 최근 증가율을 계산하는데 필요한 자료들이 결측치(NaN)이었기 때문이다.

# %%
np.corrcoef(data_result['고령자비율'],data_result['소계'])
# Out:
# array([[ 1.        , -0.44225083],
#        [-0.44225083,  1.        ]])

# %%
np.corrcoef(data_result['외국인비율'],data_result['소계'])
# Out:
# array([[ 1.        , -0.06215538],
#        [-0.06215538,  1.        ]])

# %%
np.corrcoef(data_result['인구수'],data_result['소계'])
# Out:
# array([[1.        , 0.38064812],
#        [0.38064812, 1.        ]])

# %%
data_result.sort_values(by='소계',ascending = False).head()
# Out:
#      구별    소계        최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 0   강남구  5221  2852.045267  549898  544804   5094  72602  0.926354  13.202812
# 4   관악구  3985  3040.046512  516662  499374  17288  76664  3.346095  14.838328
# 6   구로구  3227  1946.042254  438308  405837  32471  67432  7.408261  15.384615
# 16  성북구  3003  1663.541720  454532  442494  12038  72172  2.648438  15.878310
# 21  은평구  2962  1256.886447  482509  478019   4490  82245  0.930553  17.045278

# %%
data_result.sort_values(by='인구수',ascending = False).head()
# Out:
#      구별    소계        최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 17  송파구  1586   656.000000  680883  674095   6788  89539  0.996941  13.150424
# 3   강서구  1617  1259.981735  595703  589302   6401  85992  1.074529  14.435381
# 0   강남구  5221  2852.045267  549898  544804   5094  72602  0.926354  13.202812
# 8   노원구  1906  1301.432432  535495  531037   4458  82682  0.832501  15.440294
# 4   관악구  3985  3040.046512  516662  499374  17288  76664  3.346095  14.838328

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure
plt.plot([1,2,3,4,5,6,7,8,3,2,1,0])
plt.show()

# %%
import numpy as np
t = np.arange(0,12,0.01)
y = np.sin(t)

# %%
plt.figure(figsize=(10,5))
plt.plot(t,y)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(t,y)
plt.grid()
plt.xlabel('time')
plt.ylabel('Aamplitude')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(t,np.sin(t))
plt.plot(t,np.cos(t))
plt.grid()
plt.xlabel('time')
plt.ylabel('Aamplitude')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(t,np.sin(t),label = 'sin')
plt.plot(t,np.cos(t),label = 'cos')
plt.grid()
plt.legend()
plt.xlabel('time')
plt.ylabel('Aamplitude')
plt.show()

# %%
t = [0,1,2,3,4,5,6]
y = [1,4,5,7,4,2,3]
plt.figure(figsize=(10,6))
plt.plot(t,y,color='green')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(t,y,color='green',linestyle='dashed')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(t,y,color='green',linestyle='dashed',marker ='o')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(t,y,color='green',linestyle='dashed',marker ='o',markerfacecolor='blue',markersize=12)
plt.xlim([-0.5,6.5])
plt.ylim([0.5,9.5])
plt.show()

# %%
colormap = t
plt.figure(figsize=(10,6))
plt.scatter(t,y,s=50,c=colormap,marker='>')
plt.colorbar()
plt.show()

# %%
s1 = np.random.normal(loc = 0 , scale =1, size=1000)
s2 = np.random.normal(loc = 5 , scale =0.5, size=1000)
s3 = np.random.normal(loc = 10 , scale =2, size=1000)

# %%
plt.figure(figsize=(10,6))
plt.plot(s1,label='s1')
plt.plot(s2,label='s2')
plt.plot(s3,label='s3')
plt.legend()
plt.show()

# %%
import platform

from matplotlib import font_manager,rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() =='Darwin':
    rc('font',family='AppleGothic')
elif platform.system() =='Windows':
    path='c:/Windows/Fonts/malgun.ttf'
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font',family=font_name)
else:
    print('Unknown')

# %%
data_result.head()
# Out:
#     구별    소계        최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 0  강남구  5221  2852.045267  549898  544804   5094  72602  0.926354  13.202812
# 1  강동구  1879  1318.062706  457042  452646   4396  66401  0.961837  14.528424
# 2  강북구  1265   834.275720  316750  312985   3765  61660  1.188635  19.466456
# 3  강서구  1617  1259.981735  595703  589302   6401  85992  1.074529  14.435381
# 4  관악구  3985  3040.046512  516662  499374  17288  76664  3.346095  14.838328

# %%
data_result.set_index('구별',inplace=True)
data_result.head()
# Out:
#         소계        최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 구별
# 강남구   5221  2852.045267  549898  544804   5094  72602  0.926354  13.202812
# 강동구   1879  1318.062706  457042  452646   4396  66401  0.961837  14.528424
# 강북구   1265   834.275720  316750  312985   3765  61660  1.188635  19.466456
# 강서구   1617  1259.981735  595703  589302   6401  85992  1.074529  14.435381
# 관악구   3985  3040.046512  516662  499374  17288  76664  3.346095  14.838328
# 광진구   1581   838.617021  365990  350417  15573  48989  4.255034  13.385338
# 구로구   3227  1946.042254  438308  405837  32471  67432  7.408261  15.384615
# 금천구   1634  3039.962963  251370  232583  18787  38508  7.473843  15.319251
# 노원구   1906  1301.432432  535495  531037   4458  82682  0.832501  15.440294
# 도봉구    858   626.040609  333495  331238   2257  60023  0.676772  17.998171
# 동대문구  2003          NaN  362793  346156  16637  60367  4.585811  16.639516
# ...

# %%
#CCTV현황 그래프로 분석하기
data_result['소계'].plot(kind='barh',grid=True,figsize=(10,10))
plt.show()

# %%
data_result['소계'].sort_values().plot(kind='barh',grid=True,figsize=(10,10))
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.scatter(data_result['인구수'],data_result['소계'],s=50)
plt.xlabel('인구수')
plt.ylabel('CCTV')
plt.grid()
plt.show()

# %%
fp1 = np.polyfit(data_result['인구수'],data_result['소계'],1)
fp1
# Out:
# array([2.88522756e-03, 1.06403852e+03])

# %%
f1 = np.poly1d(fp1)
fx = np.linspace(100000,700000,100)

# %%
plt.figure(figsize=(10,10))
plt.scatter(data_result['인구수'],data_result['소계'],s=50)
plt.plot(fx,f1(fx),ls='dashed',lw=3,color ='g')
plt.xlabel('인구수')
plt.ylabel('CCTV')
plt.grid()
plt.show()
